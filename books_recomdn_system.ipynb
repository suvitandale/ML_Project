# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv("Books.csv")
users = pd.read_csv("Users.csv")
ratings = pd.read_csv("Ratings.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_86364\2906776592.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("Books.csv")

# %%
books.head(5)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Popularity Based Recommandation

# %%
rating_with_name = ratings.merge(books,on='ISBN')
num_rating_df = rating_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num-Rating'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num-Rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = rating_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg-Rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg-Rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num-Rating  \
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
#         avg-Rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# 4         0.000000
# ...            ...
# 241066    0.000000
# 241067    5.250000
# 241068    7.000000
# 241069    2.666667
# 241070    4.000000
#
# [241071 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num-Rating']>200].sort_values('avg-Rating',ascending=False).head(50)
popular_df
# Out:
#                                             Book-Title  num-Rating  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 3         Harry Potter and the Goblet of Fire (Book 4)         387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)         278
# 9    Harry Potter and the Order of the Phoenix (Boo...         347
# 13       Ender's Game (Ender Wiggins Saga (Paperback))         249
# 17    Harry Potter and the Chamber of Secrets (Book 2)         556
# 20   The Hobbit : The Enchanting Prelude to The Lor...         281
# 21   The Fellowship of the Ring (The Lord of the Ri...         368
# 30   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 32      The Two Towers (The Lord of the Rings, Part 2)         260
# 43                               To Kill a Mockingbird         510
# 51                                   The Da Vinci Code         898
# 57                  The Five People You Meet in Heaven         430
# 59                              The Catcher in the Rye         449
# 66   The Return of the King (The Lord of the Rings,...         211
# 76                           The Lovely Bones: A Novel        1295
# 77                                    The Great Gatsby         205
# 79                                                1984         284
# 88                            Prodigal Summer: A Novel         253
# 89                                          Neverwhere         265
# 94                             The Secret Life of Bees         774
# 100  Stupid White Men ...and Other Sorry Excuses fo...         283
# 101  Tuesdays with Morrie: An Old Man, a Young Man,...         493
# 104                The Red Tent (Bestselling Backlist)         723
# 105                                    Brave New World         226
# 110               The Hitchhiker's Guide to the Galaxy         268
# 119   Nickel and Dimed: On (Not) Getting By in America         335
# 121                                    The Tao of Pooh         211
# 123                                        Animal Farm         233
# 133                                      Into the Wild         252
# 136                                     Fahrenheit 451         409
# 149  A Walk in the Woods: Rediscovering America on ...         205
# 150                          Girl with a Pearl Earring         526
# 151                                              Night         202
# 156                                          Outlander         283
# 162      The Subtle Knife (His Dark Materials, Book 2)         225
# 170  The Color of Water: A Black Man's Tribute to H...         223
# 172  Where the Heart Is (Oprah's Book Club (Paperba...         585
# 173                     Seabiscuit: An American Legend         275
# 175                                         Life of Pi         664
# 179                                     The Bean Trees         389
# 182  A Child Called \It\": One Child's Courage to S...         265
# 184                                     ANGELA'S ASHES         279
# 186                                      High Fidelity         247
# 192                                        Good in Bed         490
# 194  Fast Food Nation: The Dark Side of the All-Ame...         321
# 195                                      American Gods         302
# 196                                 Skipping Christmas         322
# 202  Left Behind: A Novel of the Earth's Last Days ...         318
# 204    The Golden Compass (His Dark Materials, Book 1)         336
#
#      avg-Rating          Book-Author  \
# 0      5.852804        J. K. Rowling
# 3      5.824289        J. K. Rowling
# 5      5.737410        J. K. Rowling
# 9      5.501441        J. K. Rowling
# 13     5.409639     Orson Scott Card
# 17     5.183453        J. K. Rowling
# 20     5.007117       J.R.R. TOLKIEN
# 21     4.948370       J.R.R. TOLKIEN
# 30     4.895652        J. K. Rowling
# 32     4.880769       J.R.R. TOLKIEN
# 43     4.700000           Harper Lee
# 51     4.642539            Dan Brown
# 57     4.551163          Mitch Albom
# 59     4.545657        J.D. Salinger
# 66     4.497630       J.R.R. TOLKIEN
# 76     4.468726         Alice Sebold
# 77     4.458537  F. Scott Fitzgerald
# 79     4.454225        George Orwell
# 88     4.450593   Barbara Kingsolver
# 89     4.449057          Neil Gaiman
# 94     4.447028        Sue Monk Kidd
# 100    4.356890        Michael Moore
# 101    4.354970          MITCH ALBOM
# 104    4.334716        Anita Diamant
# 105    4.331858        Aldous Huxley
# 110    4.328358        Douglas Adams
# 119    4.289552   Barbara Ehrenreich
# 121    4.289100        Benjamin Hoff
# 123    4.274678        George Orwell
# 133    4.273810         Jon Krakauer
# 136    4.264059         Ray Bradbury
# 149    4.243902          Bill Bryson
# 150    4.218631      Tracy Chevalier
# 151    4.217822          Elie Wiesel
# 156    4.173145       DIANA GABALDON
# 162    4.124444       PHILIP PULLMAN
# 170    4.107623        James McBride
# 172    4.105983         Billie Letts
# 173    4.098182    LAURA HILLENBRAND
# 175    4.088855          Yann Martel
# 179    4.087404   Barbara Kingsolver
# 182    4.086792          Dave Pelzer
# 184    4.075269        Frank McCourt
# 186    4.056680          Nick Hornby
# 192    4.055102      Jennifer Weiner
# 194    4.037383       Eric Schlosser
# 195    4.006623          Neil Gaiman
# 196    4.006211         JOHN GRISHAM
# 202    4.003145           Tim Lahaye
# 204    4.000000       PHILIP PULLMAN
#
#                                            Image-URL-M
# 0    http://images.amazon.com/images/P/0439136350.0...
# 3    http://images.amazon.com/images/P/0439139597.0...
# 5    http://images.amazon.com/images/P/0590353403.0...
# 9    http://images.amazon.com/images/P/043935806X.0...
# 13   http://images.amazon.com/images/P/0312853238.0...
# 17   http://images.amazon.com/images/P/0439064872.0...
# 20   http://images.amazon.com/images/P/0345339681.0...
# 21   http://images.amazon.com/images/P/0345339703.0...
# 30   http://images.amazon.com/images/P/059035342X.0...
# 32   http://images.amazon.com/images/P/0345339711.0...
# 43   http://images.amazon.com/images/P/0446310786.0...
# 51   http://images.amazon.com/images/P/0385504209.0...
# 57   http://images.amazon.com/images/P/0786868716.0...
# 59   http://images.amazon.com/images/P/0316769487.0...
# 66   http://images.amazon.com/images/P/0345339738.0...
# 76   http://images.amazon.com/images/P/0316666343.0...
# 77   http://images.amazon.com/images/P/185326041X.0...
# 79   http://images.amazon.com/images/P/0451524934.0...
# 88   http://images.amazon.com/images/P/0060959037.0...
# 89   http://images.amazon.com/images/P/0380789019.0...
# 94   http://images.amazon.com/images/P/0142001740.0...
# 100  http://images.amazon.com/images/P/0060392452.0...
# 101  http://images.amazon.com/images/P/0385484518.0...
# 104  http://images.amazon.com/images/P/0312195516.0...
# 105  http://images.amazon.com/images/P/0060809833.0...
# 110  http://images.amazon.com/images/P/0671461494.0...
# 119  http://images.amazon.com/images/P/0805063897.0...
# 121  http://images.amazon.com/images/P/0140067477.0...
# 123  http://images.amazon.com/images/P/0451526341.0...
# 133  http://images.amazon.com/images/P/0385486804.0...
# 136  http://images.amazon.com/images/P/3257208626.0...
# 149  http://images.amazon.com/images/P/0767902521.0...
# 150  http://images.amazon.com/images/P/0452282152.0...
# 151  http://images.amazon.com/images/P/0553272535.0...
# 156  http://images.amazon.com/images/P/0440222915.0...
# 162  http://images.amazon.com/images/P/0375823468.0...
# 170  http://images.amazon.com/images/P/1573225789.0...
# 172  http://images.amazon.com/images/P/0446672211.0...
# 173  http://images.amazon.com/images/P/0449005615.0...
# 175  http://images.amazon.com/images/P/0151008116.0...
# 179  http://images.amazon.com/images/P/0060915544.0...
# 182  http://images.amazon.com/images/P/1558743669.0...
# 184  http://images.amazon.com/images/P/0684874350.0...
# 186  http://images.amazon.com/images/P/1573225517.0...
# 192  http://images.amazon.com/images/P/0743418174.0...
# 194  http://images.amazon.com/images/P/0060938455.0...
# 195  http://images.amazon.com/images/P/0380789035.0...
# 196  http://images.amazon.com/images/P/0385505833.0...
# 202  http://images.amazon.com/images/P/0842329129.0...
# 204  http://images.amazon.com/images/P/037582345X.0...

# %%
# popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','num-Rating','avg-Rating','Book-Author','Image-URL-M']]
# popular_df.head(2)

# %%
# import pickle
# pickle.dump(popular_df,open('popular_pickle.pkl','wb'))

# %% [markdown]
# # Collaborative Filtering Based Recommended System

# %%
x = rating_with_name.groupby('User-ID').count()['Book-Rating']>200

# %%
padhe_likhe_users = x[x].index
filtered_rating = rating_with_name[rating_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [706 rows x 810 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]

# %%
pt.index[10]
# Out:
# 'A Great Deliverance'

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354  0449906736      Flashpoints: Promise and Peril in a New World
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271354          Robin Wright                1993
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271354                                  Ballantine Books
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [242135 rows x 8 columns]

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
print(pd.__version__)
# Out:
# 1.4.2
